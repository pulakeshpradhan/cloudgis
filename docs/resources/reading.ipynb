# %% [markdown]
# # Further Reading
#
# Curated resources for deepening your understanding of cloud-native remote sensing.
#
# ## Books
#
# ### Remote Sensing
#
# - **Remote Sensing and Image Interpretation** by Lillesand, Kiefer, and Chipman
# - **Introduction to Remote Sensing** by Campbell and Wynne
#
# ### Python for Geospatial
#
# - **Python for Geospatial Data Analysis** by Bonny P. McClain
# - **Geoprocessing with Python** by Chris Garrard
#
# ## Online Courses
#
# ### Pangeo Tutorial
#
# - **URL**: [tutorial.pangeo.io](https://tutorial.pangeo.io)
# - **Topics**: XArray, Dask, cloud-native workflows
#
# ### Earth Engine
#
# - **URL**: [developers.google.com/earth-engine](https://developers.google.com/earth-engine)
# - **Topics**: Earth Engine fundamentals, JavaScript/Python API
#
# ### Carpentries Geospatial
#
# - **URL**: [datacarpentry.org/geospatial-workshop](https://datacarpentry.org/geospatial-workshop)
# - **Topics**: Raster and vector data with Python
#
# ## Documentation
#
# ### XArray
#
# - [User Guide](https://docs.xarray.dev/en/stable/user-guide/index.html)
# - [Tutorial](https://tutorial.xarray.dev)
#
# ### Dask
#
# - [Best Practices](https://docs.dask.org/en/stable/best-practices.html)
# - [Array Documentation](https://docs.dask.org/en/stable/array.html)
#
# ### STAC
#
# - [Specification](https://stacspec.org)
# - [STAC Index](https://stacindex.org)
#
# ## Community
#
# ### Pangeo
#
# - **Website**: [pangeo.io](https://pangeo.io)
# - **Discourse**: [discourse.pangeo.io](https://discourse.pangeo.io)
# - **GitHub**: [github.com/pangeo-data](https://github.com/pangeo-data)
#
# ### Earth Engine Community
#
# - **Forum**: [groups.google.com/g/google-earth-engine-developers](https://groups.google.com/g/google-earth-engine-developers)
# - **GitHub**: [github.com/google/earthengine-api](https://github.com/google/earthengine-api)
#
# ## Blogs and Articles
#
# ### Pangeo Blog
#
# - [medium.com/pangeo](https://medium.com/pangeo)
#
# ### Element 84 Blog
#
# - [element84.com/blog](https://www.element84.com/blog)
#
# ## Research Papers
#
# ### Cloud-Native Geospatial
#
# - "Cloud-Native Geospatial Data Management and Analysis" (Abernathey et al., 2021)
# - "Analysis Ready Data For Land" (Lewis et al., 2018)
#
# ### STAC
#
# - "The SpatioTemporal Asset Catalog (STAC) Specification" (Holmes et al., 2020)
